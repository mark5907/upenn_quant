# %%
from IPython.display import Image
import yahoo_utils as yu
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Being a Quant
# ### Lei Yao
# ### Quant researcher @ SIG

# %%
Image('engineer_syllogism.png')

# %% [markdown]
# ### Some info about me
# * Undergrad in Chemical Engineering, HKUST, Hong Kong
# * Master in Applied Math, Columbia University NYC (2008 Aug)
# * PhD at RPI, applied probability
# * Quant researcher @ SIG, algrothmic trading at the index desk

# %% [markdown]
# ### What is Quant?

# %% [markdown]
# Data analyst, mathemtiacal models, programming
#
# Not just in Finance

# %% [markdown]
# * Sell side (Goldman Sachs, JP Morgan, etc)
#     - Pricing of financial instruments
#     - PDE, stochastic processes, Black-Schole
#
# * Buy side
#     - Developing trading strategies
#     - probability/statistics/machine learning/big data/...

# %% [markdown]
# ### Typical backgrounds
# Math, Physics, CS, EE, IEOR
#
# Technical (learn in school) + Experience (accumulate on the job)**

# %%
df = yu.get_adj_close('SPY','1990-01-02', '2016-02-22')
df = df[::-1]

# %%
df.plot(rot=45, figsize=(10,5), title='SPY_1993-2016')

# %%
Image('Deweytruman12.jpg')

# %% [markdown]
# ## Tips for quant interviews
# * Be honest about your resume
#     - coursework
#     - projects
# * Probability/statistics
# * Programming
#     - Higher frequency more programming
# * Language: C++, Python**, R, Matlab

# %% [markdown]
# ### Susquehanna International Group

# %%
Image('sig.jpg', width=500)

# %% [markdown]
# * Proprietary trading firm
#     - more freedom in trading and dress code
# * Market making (70% options volume in the U.S.)
#     - provided continuous bid/ask
# * Quantitative trading
# * Tech
#     - 5GB per day, just for US equity
#     - servers TB memories
#
# * Trader <-> Quant <-> IT

# %% [markdown]
# ## Finally
# * Financial market is complex, challenging
# * Keep your mind open, keep exploring, keep learning

# %% [markdown]
# ## Thank you
# ### Linkedin: Lei Yao, SIG
